# %% [markdown]
# # Bidirectional LSTM -- Lei Fu

# %% [markdown]
# ## <a>1. Introduction: Synthetic Sonic Curves Generation</a>

# %% [markdown]
# ### <a>1.1. Background</a>
# Well logs are interpreted/processed to estimate the in-situ petrophysical and geomechanical properties, which is essential for subsurface characterization. Various types of logs exist, and each provides distinct information about subsurface properties. Certain well logs, like gamma ray (GR), resistivity, density, and neutron logs, are considered as “easy-to-acquire” conventional well logs that are run in most of the wells. Other well logs, like nuclear magnetic resonance, dielectric dispersion, elemental spectroscopy, and sometimes sonic logs, are only run in limited number of wells.
#
# Sonic travel-time logs contain critical geomechanical information for subsurface characterization around the wellbore. Often, sonic logs are required to complete the well-seismic tie workflow or geomechanical properties prediction. When sonic logs are absent in a well or an interval, a common practice is to synthesize them based on its neighboring wells that have sonic logs. This is referred to as sonic log synthesis or pseudo sonic log generation.

# %% [markdown]
# ### <a>1.2. Problem Statement</a>
# Compressional travel-time (DTC) and shear travel-time (DTS) logs are not acquired in all the wells drilled in a field due to financial or operational constraints. Under such circumstances, machine learning techniques can be used to predict DTC and DTS logs to improve subsurface characterization. The goal of the “SPWLA’s 1st Petrophysical Data-Driven Analytics Contest” is to develop data-driven models by processing “easy-to-acquire” conventional logs from Well #1, and use the data-driven models to generate synthetic compressional and shear travel-time logs (DTC and DTS, respectively) in Well #2. A robust data-driven model for the desired sonic-log synthesis will result in low prediction errors, which can be quantified in terms of Root Mean Squared Error by comparing the synthesized and the original DTC and DTS logs.
#
# You are provided with two datasets: train.csv and test.csv. You need to build a generalizable data-driven models using train dataset. Following that, you will deploy the newly developed data-driven models on test dataset to predict DTS and DTC logs. The data-driven model should use feature sets derived from the following 7 logs: Caliper, Neutron, Gamma Ray, Deep Resistivity, Medium Resistivity, Photo-electric factor and density. The data-driven model should synthesize two target logs: DTC and DTS logs.
#
# The predicted values should be in the same format as sample_submission.csv, and submit together with your notebook for evaluation.

# %% [markdown]
# ### <a>1.3. Data Decription</a>
# #### Files
# &gt; #### train.csv
# All the values equals to -999 are marked as missing values.
# - CAL - Caliper, unit in Inch,
# - CNC - Neutron, unit in dec
# - GR - Gamma Ray, unit in API
# - HRD - Deep Resisitivity, unit in Ohm per meter,
# - HRM - Medium Resistivity, unit in Ohm per meter,
# - PE - Photo-electric Factor, unit in Barn,
# - ZDEN - Density, unit in Gram per cubit meter,
# - DTC - Compressional Travel-time, unit in nanosecond per foot,
# - DTS - Shear Travel-time, unit in nanosecond per foot,
#
#
# &gt; #### test.csv
# The test data has all features that you used in the train dataset, except the two sonic curves DTC and DTS.
#
# &gt; ####  sample_submission.csv
# A valid sample submission.
# <p><font style="">
# </font></p>

# %% [markdown]
# ### <a>1.4. Evaluation Metric</a>
# We will be evaluated by the metirc `Root Mean Squared Error`.
#
# The RMSE is calculated as:
#
# $ ϵ=∑_i \sqrt{ ∑_n (y_p - y_t)^2 /n } $
#
# Where:
# - y_p is the predicted curve for DTC and DTS
# - y_t is the true value for evaluation.
#
# DTC and DTS are in the same weight during the evaluation
#
# Understanding and optimizing your predictions for this evaluation metric is paramount for this compeition.

# %% [markdown]
# ## <a>2. Imports</a>

# %% [markdown]
# <a>Top</a>

# %%
# !pip install -q git+https://github.com/tensorflow/docs
# Out:
#   Building wheel for tensorflow-docs (setup.py) ... done

# %%
# import libraries
import pandas as pd
import numpy as np

np.random.seed(7)

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sb
# import sklearn libararies
from sklearn.linear_model import LinearRegression, RidgeCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression 
from sklearn.neural_network import MLPRegressor
import matplotlib.style as style

from scipy import stats
from sklearn import svm
from sklearn.covariance import EllipticEnvelope
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

import tensorflow as tf
import random as python_random

# The below is necessary for starting Numpy generated random numbers
# in a well-defined initial state.
np.random.seed(123)

# The below is necessary for starting core Python generated random numbers
# in a well-defined state.
python_random.seed(123)

# The below set_seed() will make random number generation
# in the TensorFlow backend have a well-defined initial state.
# For further details, see:
# https://www.tensorflow.org/api_docs/python/tf/random/set_seed
tf.random.set_seed(1234)

# Seed value (can actually be different for each attribution step)
seed_value= 0

# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

CUDA_VISIBLE_DEVICES=""

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow.keras import initializers

print(tf.__version__)

# Use some functions from tensorflow_docs
# pip install -q git+https://github.com/tensorflow/docs
    
import tensorflow_docs as tfdocs
import tensorflow_docs.plots
import tensorflow_docs.modeling
from datetime import datetime

style.available

style.use('seaborn-dark')
# plt.style.use('ggplot')
# Out:
# 2.3.0

# %% [markdown]
# ## <a>3. Read Data</a>

# %% [markdown]
# <a>Top</a>

# %%
DROP_FEATURE = ['CAL','HRD','HRM','PE'] # DROP features
# DROP_FEATURE = ['CAL','HRD','HRM','PE']
REPLACE_ANOMALY = True

df1 = pd.read_csv('train.csv')
print(df1.isnull().sum(axis = 0))

print(df1.head())

# df1 = df1.iloc[20000:, :]
# df1.index = np.arange(0,len(df1.index))

start_well2 = 11000
start_well3 = 19939

x_start, x_end = 2500, 15500

plt.figure()
sb.pairplot(df1[['CNC', 'GR', 'ZDEN', 'DTC']])

plt.scatter(df1['CNC'], df1['GR'], s=20, alpha=0.2)

plt.figure()
plt.plot(df1['CAL'])
plt.ylim([0, 20])
plt.xlim([x_start, x_end])

plt.figure()
plt.plot(df1['CNC'])
plt.ylim([0, 2])
plt.xlim([x_start, x_end])

plt.figure()
plt.plot(df1['GR'])
# plt.ylim([0, 2])
plt.xlim([x_start, x_end])

plt.figure()
plt.plot(df1['HRD'])
plt.ylim([0, 20])
plt.xlim([x_start, x_end])

plt.figure()
plt.plot(df1['HRM'])
plt.ylim([0, 20])
plt.xlim([x_start, x_end])

plt.figure()
plt.plot(df1['PE'])
plt.ylim([0, 50])
plt.xlim([x_start, x_end])

plt.figure()
plt.plot(df1['ZDEN'])
plt.ylim([0, 10])
plt.xlim([x_start, x_end])

plt.figure()
plt.plot(df1['DTC'])
# plt.ylim([0, 10])
plt.xlim([x_start, x_end])

plt.figure()
plt.plot(df1['DTS'])
# plt.ylim([0, 10])
plt.xlim([x_start, x_end])

df1.drop(DROP_FEATURE, axis=1, inplace=True)
    
# print(df1['PE'][19939:].describe())
# df1['PE'][19939:] = df1['PE'][19939:] *100
# print(df1['PE'][19939:].describe())
# print(df1['PE'][:19939].describe())
# print(df1[df1.index == 19938].describe())
# print(df1.tail())

print(df1.head())
# plt.scatter(df1['DTC'], df1['DTS'], s=10, alpha=0.5)
# plt.axis((0,200,0,500))
# Out:
# CAL     0
# CNC     0
# GR      0
# HRD     0
# HRM     0
# PE      0
# ZDEN    0
# DTC     0
# DTS     0
# dtype: int64
#      CAL    CNC       GR    HRD    HRM     PE   ZDEN       DTC       DTS
# 0 -999.0 -999.0  41.4699 -999.0 -999.0 -999.0 -999.0  128.0737  319.0654
# 1 -999.0 -999.0  42.5053 -999.0 -999.0 -999.0 -999.0  127.8347  318.7825
# 2 -999.0 -999.0  43.1548 -999.0 -999.0 -999.0 -999.0  127.2307  317.3323
# 3 -999.0 -999.0  43.2410 -999.0 -999.0 -999.0 -999.0  126.2917  313.6486
# 4 -999.0 -999.0  40.3218 -999.0 -999.0 -999.0 -999.0  125.3985  307.8903
#      CNC       GR   ZDEN       DTC       DTS
# 0 -999.0  41.4699 -999.0  128.0737  319.0654
# 1 -999.0  42.5053 -999.0  127.8347  318.7825
# 2 -999.0  43.1548 -999.0  127.2307  317.3323
# 3 -999.0  43.2410 -999.0  126.2917  313.6486
# 4 -999.0  40.3218 -999.0  125.3985  307.8903

# %% [markdown]
# ## <a>4. Glimps Data</a>

# %% [markdown]
# <a>Top</a>

# %%
df1.describe()
# Out:
#                 CNC            GR          ZDEN           DTC           DTS
# count  30143.000000  30143.000000  30143.000000  30143.000000  30143.000000
# mean     -23.692615     38.959845    -20.229982    -54.891703     -9.737567
# std      157.142679    108.504554    148.809506    372.858812    440.314119
# min     -999.000000   -999.000000   -999.000000   -999.000000   -999.000000
# 25%        0.122800     17.248750      2.226700     66.304350    118.534350
# 50%        0.193600     36.821800      2.432200     78.355100    137.689300
# 75%        0.337150     58.346150      2.551350    107.022500    182.973150
# max     3490.158200   1470.253400      3.259700    155.980300    487.438400

# %%
df1.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30143 entries, 0 to 30142
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CNC     30143 non-null  float64
#  1   GR      30143 non-null  float64
#  2   ZDEN    30143 non-null  float64
#  3   DTC     30143 non-null  float64
#  4   DTS     30143 non-null  float64
# dtypes: float64(5)
# memory usage: 1.1 MB

# %% [markdown]
# ## <a>5. Exploratory Data Analysis</a>

# %% [markdown]
# <a>Top</a>

# %% [markdown]
# Exploratory Data Analysis (EDA) is an open-ended process where we calculate statistics and make figures to find trends, missing values, outliers, anomalies, patterns, or relationships within the data.

# %%
# Replace all -999 with nan value
df1.replace(['-999', -999], np.nan, inplace=True)
print(df1.isnull().sum(axis = 0))
df1.describe()
# Out:
# CNC      735
# GR       254
# ZDEN     681
# DTC     4054
# DTS     4865
# dtype: int64
#                 CNC            GR          ZDEN           DTC           DTS
# count  29408.000000  29889.000000  29462.000000  26089.000000  25278.000000
# mean       0.683437     47.780541      2.393818     91.814381    180.655730
# std       30.689679     51.377519      0.196276     24.337910     81.141960
# min       -0.102800     -0.146000     -1.923800     49.970500     80.580400
# 25%        0.127100     18.026100      2.234800     71.357000    129.446625
# 50%        0.198500     37.082200      2.439600     85.237600    144.593050
# 75%        0.343100     58.532800      2.553000    112.112600    191.475125
# max     3490.158200   1470.253400      3.259700    155.980300    487.438400

# %%
matplotlib.rcParams['figure.figsize'] = (16.0, 9.0)

# Plot well logs
def log_plot(z, log, x_label='', y_label='Sample', title='', lineWidth=1):
    plt.plot(log, z, linewidth=lineWidth)
    plt.ylim(z.max(), z.min())
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.tick_params(labeltop=True, labelright=True)
    plt.grid(b=None, which='both', axis='y')
    
# Plot well logs
def log_plot2(z, log, x_label='Sample', y_label='', title='', lineWidth=1):
    plt.plot(z, log, linewidth=lineWidth)
    plt.xlim(z.min(), z.max())
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.tick_params(labeltop=True, labelright=True)
    plt.grid(b=None, which='both', axis='y')

# %%
# load test data from well 2
df2 = pd.read_csv('test.csv')

print(df2.isnull().sum(axis = 0), df2.shape)

# Remove missing 
for col in df2.columns.tolist():
    df2[col][df2[col]==-999] = np.nan

df2.dropna(axis=0, inplace=True)
df2.describe()
# Out:
# CAL     0
# CNC     0
# GR      0
# HRD     0
# HRM     0
# PE      0
# ZDEN    0
# dtype: int64 (11088, 7)
#                 CAL           CNC  ...            PE          ZDEN
# count  11088.000000  11088.000000  ...  11088.000000  11088.000000
# mean       8.634049      0.158501  ...      7.353522      2.475884
# std        0.044064      0.091298  ...      1.239075      0.149440
# min        8.500000      0.009800  ...      4.760800      2.033400
# 25%        8.625000      0.091700  ...      6.528075      2.378175
# 50%        8.625000      0.128300  ...      7.881700      2.533600
# 75%        8.671900      0.213500  ...      8.308325      2.581800
# max        8.875000      0.559400  ...     13.840700      3.024800
#
# [8 rows x 7 columns]

# %%
df1_orig = df1.copy()

# %%
# Insert index as depth column
# df1.insert(0, 'DEP', df1.index) 

ilog = 2 # ['CAL', 'CNC', 'GR', 'HRD', 'HRM', 'PE', 'ZDEN', 'DTC', 'DTS']

# Plot 1 - before vs DTC/DTS, 2 - before vs after, 3 - after vs DTC/DTS 
compare = 3

logs = df1.columns.tolist()
item = logs[ilog]

anomaly = pd.DataFrame(columns=df1.columns)

# Interpolate values out of range
def interpolateValue(item, maxVal, minVal = float('-inf'), df=df1, df_orig=df1_orig):
    ind = ((df_orig[item] > maxVal) | (df_orig[item] < minVal))
    df.loc[ind,item] = np.nan
    
    # print(df[ind == True].index, df[ind][item])
    
    for i,x in enumerate(ind):
        if x:
            j = i + 1
            while ind[j]:
                j += 1
            df.iloc[i-1:j+1] = df.iloc[i-1:j+1].interpolate()
    
    # print(df[ind == True].index, df[ind][item])
    return df_orig.loc[ind, item]

print(df1.isnull().sum(axis = 0))

if item == 'CAL':
    pass
elif item == 'CNC':
    # print(df1[ind == True].index, df1[ind][item])
    anomaly = interpolateValue(item, 0.9)
    # print(df1[ind == True].index, df1[ind][item])
    # print(df1.isnull().sum(axis = 0))
elif item == 'GR':
    anomaly = interpolateValue(item, 400)
elif item == 'HRD':
    anomaly = interpolateValue(item, 250)
elif item == 'HRM':
    anomaly = interpolateValue(item, 500)
elif item == 'PE':
    anomaly = interpolateValue(item, 25)
elif item == 'ZDEN':
    anomaly = interpolateValue(item, 3.1, 1.8)
    
# Plot 1 - before vs DTC/DTS, 2 - before vs after, 3 - after vs DTC/DTS 
plt.subplots(nrows=2, ncols=2, figsize=(16,9))

plt.subplot(2, 1, 1)
if compare == 3:
#     log_plot2(df2.index+len(df1.index)-len(df2.index), df2[item])
    log_plot2(df1.index, df1[item], item, title=item)
else:
    plt.scatter(anomaly.index, anomaly,
                c='red', marker='o', s=20, alpha=0.5)
    log_plot2(df1_orig.index, df1_orig[item], item, title=item)

plt.subplot(2, 1, 2)
if compare == 2:
    log_plot2(df1.index, df1[item], item, title=item)
else:
    plt.subplot(2, 1, 2)
    log_plot2(df1.index, df1['DTC'], 'DTC')
    log_plot2(df1.index, df1['DTS'], 'DTS', title='DTC & DTS')

plt.figure()
plt.scatter(anomaly.index, anomaly, label="anomalies")
plt.title(item + " anomalies")

print(anomaly.describe())
print(df1.isnull().sum(axis = 0))

# plt.figure()
# plt.plot(df1['PE'][19938:19940])
# print(df1['PE'][19939:].describe())
# Out:
# CNC      735
# GR       254
# ZDEN     681
# DTC     4054
# DTS     4865
# dtype: int64
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:67: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# count    121.000000
# mean       1.235612
# std        0.768926
# min       -1.923800
# 25%        0.978900
# 50%        1.353400
# 75%        1.712800
# max        3.259700
# Name: ZDEN, dtype: float64
# CNC      735
# GR       254
# ZDEN     681
# DTC     4054
# DTS     4865
# dtype: int64

# %%
endPoint = 30000
i = 1
ymax = [0, 1, 0, 20, 20, 0, 0]

fig, ax1 = plt.subplots()

color = 'tab:orange'
ax1.set_xlabel('point')
ax1.set_ylabel('DTS/DTC', color=color)
ax1.plot(df1.index[:endPoint], df1['DTS'][:endPoint]/df1['DTC'][:endPoint], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel(logs[i], color=color)  # we already handled the x-label with ax1
ax2.plot(df1.index[:endPoint], df1[logs[i]][:endPoint], color=color)
ax2.tick_params(axis='y', labelcolor=color)
if ymax[i]:
    ax2.set_ylim([0, ymax[i]])

fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.figure()
plt.plot(df2[logs[i]][:endPoint])
if ymax[i]:
    plt.ylim([0, ymax[i]])

plt.figure()
plt.plot(df2[logs[i]][1980:2030])
    
# plt.figure()
# df3 = pd.read_csv('real_result_20perc.csv')
# plt.plot(df3['DTS'][:endPoint]/df3['DTC'][:endPoint])

# %%
i = 2

plt.figure()
plt.subplots(nrows=2, ncols=2, figsize=(16,9))
plt.subplot(2, 1, 1)
plt.plot(df2[logs[i]])
plt.plot(df1_orig.index[19939:]-19939, df1_orig[logs[i]][19939:])
plt.title(logs[i])
plt.xlim([0, len(df2.index)])
# plt.ylim([0, 500])

plt.subplot(2, 1, 2)
plt.plot(df1_orig.index[19939:]-19939, df1_orig['DTC'][19939:])
plt.plot(df1_orig.index[19939:]-19939, df1_orig['DTS'][19939:])
plt.xlim([0, len(df2.index)])
# Out:
# (0.0, 11088.0)

# %%
if REPLACE_ANOMALY:
    print(df1.isnull().sum(axis = 0))
    print(df1.describe())

    for item in logs[:-2]:
        if item == 'CAL':
            pass
        elif item == 'CNC':
            anomaly = interpolateValue(item, 0.9)
        elif item == 'GR':
            anomaly = interpolateValue(item, 400)
        elif item == 'HRD':
            anomaly = interpolateValue(item, 25)
        elif item == 'HRM':
            anomaly = interpolateValue(item, 25)
        elif item == 'PE':
            anomaly = interpolateValue(item, 25)
        elif item == 'ZDEN':
            anomaly = interpolateValue(item, 3.1, 1.8)

    print(df1.isnull().sum(axis = 0))
    print(df1.describe())
# Out:
# CNC      735
# GR       254
# ZDEN     681
# DTC     4054
# DTS     4865
# dtype: int64
#                 CNC            GR          ZDEN           DTC           DTS
# count  29408.000000  29889.000000  29462.000000  26089.000000  25278.000000
# mean       0.683437     47.780541      2.397328     91.814381    180.655730
# std       30.689679     51.377519      0.176521     24.337910     81.141960
# min       -0.102800     -0.146000      1.807900     49.970500     80.580400
# 25%        0.127100     18.026100      2.235100     71.357000    129.446625
# 50%        0.198500     37.082200      2.439600     85.237600    144.593050
# 75%        0.343100     58.532800      2.553000    112.112600    191.475125
# max     3490.158200   1470.253400      3.096600    155.980300    487.438400
# CNC      735
# GR       254
# ZDEN     681
# DTC     4054
# DTS     4865
# dtype: int64
#                 CNC            GR          ZDEN           DTC           DTS
# count  29408.000000  29889.000000  29462.000000  26089.000000  25278.000000
# mean       0.247720     47.455227      2.397328     91.814381    180.655730
# std        0.155744     47.074419      0.176521     24.337910     81.141960
# min       -0.102800     -0.146000      1.807900     49.970500     80.580400
# 25%        0.126800     18.026100      2.235100     71.357000    129.446625
# 50%        0.198300     37.082200      2.439600     85.237600    144.593050
# 75%        0.342025     58.532800      2.553000    112.112600    191.475125
# max        0.886900    394.813600      3.096600    155.980300    487.438400

# %%
print(df1.shape)

# remove all rows that contains missing value
df1.dropna(axis=0, inplace=True)

print(df1.shape)

# sb.pairplot(df1[['CNC', 'GR', 'ZDEN', 'DTC', 'DTS']])
# Out:
# (30143, 5)
# (20688, 5)

# %%
# Remove outliers
each_feature = False # remove anomalies for each feature
method = 1  # 1-OneClassSVM; 2-IsolationForest; 3-LocalOutlierFactor
outliers_fraction = 25 / 20525

# define outlier/anomaly detection methods to be compared
anomaly_algorithms = [
    ("Robust covariance", EllipticEnvelope(contamination=outliers_fraction)),
    ("One-Class SVM", svm.OneClassSVM(nu=outliers_fraction, kernel="rbf", gamma='scale')),
    ("Isolation Forest", IsolationForest(contamination=outliers_fraction, random_state=42, behaviour="new")),
    ("Local Outlier Factor", LocalOutlierFactor(n_neighbors=35, contamination=outliers_fraction))] # 'auto'))]


# if method == 1:
#     # clf = svm.OneClassSVM(nu=outliers_fraction, gamma=0.1).fit(df1)
#     clf = svm.OneClassSVM(nu=outliers_fraction, gamma='scale').fit(df1[['CNC']])
#     normal = clf.fit_predict(df1[['CNC']])
# elif method == 2:
#     clf = IsolationForest(contamination=outliers_fraction, random_state=42, behaviour="new")
#     normal = clf.fit_predict(df1[['CNC']])
# elif method == 3:
#     clf = LocalOutlierFactor(n_neighbors=35, contamination='auto') #=outliers_fraction)
#     normal = clf.fit_predict(df1[['CNC']])

normal = np.zeros(df1.shape[0], )

print('method = ', method, ': ', anomaly_algorithms[method][0])

if each_feature:
    # detect anomaly for each features
    for i, item in enumerate(logs[:-2]):
        clf = anomaly_algorithms[method][1].fit_predict(df1[[item]])

        plt.figure(figsize=(12.0, 40.0))
        # log_plot(df1.index, df1[item])
        log_plot(df1.index[clf==1], df1[item][clf==1], item, title=item)
        # plt.xlim(0, 1.1)
        print(item, -sum(clf[clf==-1]))

        normal += clf
        
        print(normal.shape)
        
    # remove anamoly
    if method in [0, 1, 2, 3]:
        df1 = df1[normal==df1.shape[1]-2]
        print(df1.shape)
else:
    clf = anomaly_algorithms[method][1].fit_predict(df1)

    for i, item in enumerate(logs):
        plt.figure(figsize=(12.0, 40.0))
        log_plot(df1.index, df1[item])
        log_plot(df1.index[clf==1], df1[item][clf==1], item, title=item)

    print("Number of anomalies = ", -sum(clf[clf==-1]))

    # remove anamoly
    if method in [0, 1, 2, 3]:
        df1 = df1[clf==1]
        print(df1.shape)
# Out:
# method =  1 :  One-Class SVM
# Number of anomalies =  25
# (20663, 5)

# %% [markdown]
# ## <a>6. Build Machine Learning Models</a>

# %% [markdown]
# <a>Top</a>

# %%
def result_plot(y_predict, y_real):
    # check the accuracy of predicted data and plot the result
    print('Root Mean Square Error is:', '{:.5f}'.format(np.sqrt(mean_squared_error(y_real, y_predict))))
    print('DTC:', '{:.5f}'.format(np.sqrt(mean_squared_error(y_real[:, 0], y_predict[:, 0]))))
    print('DTS:', '{:.5f}'.format(np.sqrt(mean_squared_error(y_real[:, 1], y_predict[:, 1]))))
    plt.subplots(nrows=2, ncols=2, figsize=(16,10))
    plt.subplot(2, 2, 1)
    plt.plot(y_real[:, 0])
    plt.plot(y_predict[:, 0])
    plt.legend(['True', 'Predicted'])
    plt.xlabel('Sample')
    plt.ylabel('DTC')
    plt.title('DTC Prediction Comparison')

    plt.subplot(2, 2, 2)
    plt.plot(y_real[:, 1])
    plt.plot(y_predict[:, 1])
    plt.legend(['True', 'Predicted'])
    plt.xlabel('Sample')
    plt.ylabel('DTS')
    plt.title('DTS Prediction Comparison')
    
    plt.subplot(2, 2, 3)
    plt.scatter(y_real[:, 0], y_predict[:, 0])
    plt.xlabel('Real Value')
    plt.ylabel('Predicted Value')
    plt.title('DTC Prediction Comparison')
    
    plt.subplot(2, 2, 4)
    plt.scatter(y_real[:, 1], y_predict[:, 1])
    plt.xlabel('Real Value')
    plt.ylabel('Predicted Value')
    plt.title('DTS Prediction Comparison')

    plt.show()
    
    return np.sqrt(mean_squared_error(y_real, y_predict))

# %%
# Train a binary classifier
print(df1.head())

# Insert label ROCK column
if 'ROCK' not in df1.columns:
    df1.insert(0, 'ROCK', 1)

df1.loc[:, 'ROCK'] = 1
df1.loc[df1.index > 5000, 'ROCK'] = 0 

# plt.subplots(nrows=2, ncols=1, figsize=(16,10))
# plt.subplot(2, 1, 1)
# plt.plot(df1['ROCK'])
# plt.subplot(2, 1, 2)
# plt.plot(df1['DTC'])

# print(len(df1.index))

# split into input (X) and output (y) variables
dataset = np.array(df1)
XData = dataset[:,1:-2]
YData = dataset[:,0]

X, x_test, y, y_test = train_test_split(XData, YData, stratify=YData, test_size=0.25)

# define the keras model
model_bc = keras.Sequential()
model_bc.add(layers.Dense(12, input_dim=len(df1.columns)-3, activation='relu'))
model_bc.add(layers.Dense(8, activation='relu'))
model_bc.add(layers.Dense(1, activation='sigmoid'))

# compile the keras model
model_bc.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# The patience parameter is the amount of epochs to check for improvement
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=1000)

if True:
    history = model_bc.fit(
        XData, YData,
        batch_size=5000, epochs=400, 
        verbose=1,
        callbacks=[early_stop, tfdocs.modeling.EpochDots()],
        shuffle=True)
else:
    history = model_bc.fit(
        X, y,
        batch_size=5000, epochs=4000, 
        validation_data=(x_test, y_test), 
#         validation_split = 0.00002,
        verbose=1,
        callbacks=[early_stop, tfdocs.modeling.EpochDots()],
        shuffle=True)
    
    plotter = tfdocs.plots.HistoryPlotter(smoothing_std=2)
    plotter.plot({'Basic': history}, metric = "accuracy")
    plt.ylabel('accuracy')
    plt.ylim([0,1])
# Out:
#         CNC       GR    ZDEN       DTC       DTS
# 573  0.5173  57.1903  2.3510  125.9611  306.8676
# 574  0.4966  63.1593  2.4055  125.9726  305.8347
# 575  0.4433  64.5217  2.4579  125.8528  305.9089
# 576  0.4309  63.0144  2.4219  125.7362  305.1737
# 577  0.4469  60.8421  2.3138  125.9774  304.4476
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# Epoch 1/400
# 1/5 [=====>........................] - ETA: 0s - loss: 12.1092 - accuracy: 0.1982WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
#
# Epoch: 0, accuracy:0.2053,  loss:11.5057,
# 5/5 [==============================] - 0s 3ms/step - loss: 11.5057 - accuracy: 0.2053
# Epoch 2/400
# 1/5 [=====>........................] - ETA: 0s - loss: 10.4750 - accuracy: 0.2200WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 2ms/step - loss: 9.8230 - accuracy: 0.2217
# Epoch 3/400
# 1/5 [=====>........................] - ETA: 0s - loss: 8.8777 - accuracy: 0.2278WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 2ms/step - loss: 8.1418 - accuracy: 0.2425
# Epoch 4/400
# 1/5 [=====>........................] - ETA: 0s - loss: 6.7449 - accuracy: 0.2694WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 6.4616 - accuracy: 0.2748
# Epoch 5/400
# 1/5 [=====>........................] - ETA: 0s - loss: 5.2919 - accuracy: 0.3106WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 4.7986 - accuracy: 0.3309
# Epoch 6/400
# 1/5 [=====>........................] - ETA: 0s - loss: 3.6460 - accuracy: 0.3884WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 2ms/step - loss: 3.1007 - accuracy: 0.4194
# Epoch 7/400
# 1/5 [=====>........................] - ETA: 0s - loss: 1.8844 - accuracy: 0.4914WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3355 - accuracy: 0.6002
# Epoch 8/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4688 - accuracy: 0.7844WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4710 - accuracy: 0.8171
# Epoch 9/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6550 - accuracy: 0.8194WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6832 - accuracy: 0.8291
# Epoch 10/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7859 - accuracy: 0.8258WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7857 - accuracy: 0.8291
# Epoch 11/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7898 - accuracy: 0.8256WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7515 - accuracy: 0.8291
# Epoch 12/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6344 - accuracy: 0.8416WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6381 - accuracy: 0.8291
# Epoch 13/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5523 - accuracy: 0.8256WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5001 - accuracy: 0.8291
# Epoch 14/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4204 - accuracy: 0.8302WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4166 - accuracy: 0.8207
# Epoch 15/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4466 - accuracy: 0.7852WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4545 - accuracy: 0.7790
# Epoch 16/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4447 - accuracy: 0.7866WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4248 - accuracy: 0.8021
# Epoch 17/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4044 - accuracy: 0.8308WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4110 - accuracy: 0.8291
# Epoch 18/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4250 - accuracy: 0.8250WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4169 - accuracy: 0.8291
# Epoch 19/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4137 - accuracy: 0.8270WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4065 - accuracy: 0.8291
# Epoch 20/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4151 - accuracy: 0.8196WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4042 - accuracy: 0.8220
# Epoch 21/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3970 - accuracy: 0.8240WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4031 - accuracy: 0.8220
# Epoch 22/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4020 - accuracy: 0.8270WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3998 - accuracy: 0.8291
# Epoch 23/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4140 - accuracy: 0.8202WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3993 - accuracy: 0.8291
# Epoch 24/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3952 - accuracy: 0.8300WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3970 - accuracy: 0.8291
# Epoch 25/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3989 - accuracy: 0.8284WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3955 - accuracy: 0.8285
# Epoch 26/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3839 - accuracy: 0.8352WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3941 - accuracy: 0.8287
# Epoch 27/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3878 - accuracy: 0.8326WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3925 - accuracy: 0.8291
# Epoch 28/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3930 - accuracy: 0.8286WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3912 - accuracy: 0.8291
# Epoch 29/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3914 - accuracy: 0.8280WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3896 - accuracy: 0.8291
# Epoch 30/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3840 - accuracy: 0.8320WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3881 - accuracy: 0.8291
# Epoch 31/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3874 - accuracy: 0.8288WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3867 - accuracy: 0.8291
# Epoch 32/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3872 - accuracy: 0.8290WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3852 - accuracy: 0.8291
# Epoch 33/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3798 - accuracy: 0.8320WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3837 - accuracy: 0.8291
# Epoch 34/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3858 - accuracy: 0.8268WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3821 - accuracy: 0.8291
# Epoch 35/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3912 - accuracy: 0.8220WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3807 - accuracy: 0.8291
# Epoch 36/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3855 - accuracy: 0.8258WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3793 - accuracy: 0.8291
# Epoch 37/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3782 - accuracy: 0.8284WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3775 - accuracy: 0.8291
# Epoch 38/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3700 - accuracy: 0.8342WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3760 - accuracy: 0.8291
# Epoch 39/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3733 - accuracy: 0.8294WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3745 - accuracy: 0.8291
# Epoch 40/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3742 - accuracy: 0.8302WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3729 - accuracy: 0.8291
# Epoch 41/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3641 - accuracy: 0.8354WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3716 - accuracy: 0.8291
# Epoch 42/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3599 - accuracy: 0.8364WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3698 - accuracy: 0.8291
# Epoch 43/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3783 - accuracy: 0.8214WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3687 - accuracy: 0.8291
# Epoch 44/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3684 - accuracy: 0.8280WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3668 - accuracy: 0.8291
# Epoch 45/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3622 - accuracy: 0.8314WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3652 - accuracy: 0.8291
# Epoch 46/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3651 - accuracy: 0.8276WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3637 - accuracy: 0.8291
# Epoch 47/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3620 - accuracy: 0.8296WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3622 - accuracy: 0.8291
# Epoch 48/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3650 - accuracy: 0.8260WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3605 - accuracy: 0.8291
# Epoch 49/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3544 - accuracy: 0.8320WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3592 - accuracy: 0.8291
# Epoch 50/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3477 - accuracy: 0.8362WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3574 - accuracy: 0.8291
# Epoch 51/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3569 - accuracy: 0.8296WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3560 - accuracy: 0.8291
# Epoch 52/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3422 - accuracy: 0.8360WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3541 - accuracy: 0.8291
# Epoch 53/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3584 - accuracy: 0.8228WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3526 - accuracy: 0.8291
# Epoch 54/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3528 - accuracy: 0.8294WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3512 - accuracy: 0.8291
# Epoch 55/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3522 - accuracy: 0.8286WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3496 - accuracy: 0.8291
# Epoch 56/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3500 - accuracy: 0.8278WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3480 - accuracy: 0.8291
# Epoch 57/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3553 - accuracy: 0.8226WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3463 - accuracy: 0.8291
# Epoch 58/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3422 - accuracy: 0.8326WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3447 - accuracy: 0.8291
# Epoch 59/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3408 - accuracy: 0.8326WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3432 - accuracy: 0.8291
# Epoch 60/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3365 - accuracy: 0.8334WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3417 - accuracy: 0.8291
# Epoch 61/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3415 - accuracy: 0.8294WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3401 - accuracy: 0.8291
# Epoch 62/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3440 - accuracy: 0.8248WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3387 - accuracy: 0.8291
# Epoch 63/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3385 - accuracy: 0.8284WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3370 - accuracy: 0.8291
# Epoch 64/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3418 - accuracy: 0.8258WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3355 - accuracy: 0.8291
# Epoch 65/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3493 - accuracy: 0.8184WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3339 - accuracy: 0.8291
# Epoch 66/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3270 - accuracy: 0.8338WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3323 - accuracy: 0.8291
# Epoch 67/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3207 - accuracy: 0.8370WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3307 - accuracy: 0.8291
# Epoch 68/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3276 - accuracy: 0.8310WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3293 - accuracy: 0.8291
# Epoch 69/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3310 - accuracy: 0.8268WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3276 - accuracy: 0.8291
# Epoch 70/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3316 - accuracy: 0.8262WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3261 - accuracy: 0.8291
# Epoch 71/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3248 - accuracy: 0.8314WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3245 - accuracy: 0.8291
# Epoch 72/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3303 - accuracy: 0.8226WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3231 - accuracy: 0.8291
# Epoch 73/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3265 - accuracy: 0.8240WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3215 - accuracy: 0.8291
# Epoch 74/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3125 - accuracy: 0.8340WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3201 - accuracy: 0.8291
# Epoch 75/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3085 - accuracy: 0.8370WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3185 - accuracy: 0.8291
# Epoch 76/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3130 - accuracy: 0.8324WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3169 - accuracy: 0.8291
# Epoch 77/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3148 - accuracy: 0.8308WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3155 - accuracy: 0.8291
# Epoch 78/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3140 - accuracy: 0.8296WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3140 - accuracy: 0.8291
# Epoch 79/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3137 - accuracy: 0.8306WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3125 - accuracy: 0.8291
# Epoch 80/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3133 - accuracy: 0.8278WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3111 - accuracy: 0.8291
# Epoch 81/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3078 - accuracy: 0.8306WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3095 - accuracy: 0.8291
# Epoch 82/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3160 - accuracy: 0.8230WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3080 - accuracy: 0.8291
# Epoch 83/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3034 - accuracy: 0.8308WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3065 - accuracy: 0.8291
# Epoch 84/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3089 - accuracy: 0.8248WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3050 - accuracy: 0.8291
# Epoch 85/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2985 - accuracy: 0.8350WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3036 - accuracy: 0.8291
# Epoch 86/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3018 - accuracy: 0.8296WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3021 - accuracy: 0.8291
# Epoch 87/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3080 - accuracy: 0.8232WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3007 - accuracy: 0.8291
# Epoch 88/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2953 - accuracy: 0.8324WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2992 - accuracy: 0.8291
# Epoch 89/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3004 - accuracy: 0.8284WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2978 - accuracy: 0.8291
# Epoch 90/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2950 - accuracy: 0.8296WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2963 - accuracy: 0.8291
# Epoch 91/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2964 - accuracy: 0.8286WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2952 - accuracy: 0.8291
# Epoch 92/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2874 - accuracy: 0.8362WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2938 - accuracy: 0.8291
# Epoch 93/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2844 - accuracy: 0.8362WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2922 - accuracy: 0.8291
# Epoch 94/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2863 - accuracy: 0.8326WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2909 - accuracy: 0.8291
# Epoch 95/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2855 - accuracy: 0.8296WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2892 - accuracy: 0.8291
# Epoch 96/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2971 - accuracy: 0.8222WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2877 - accuracy: 0.8291
# Epoch 97/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2796 - accuracy: 0.8362WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2864 - accuracy: 0.8291
# Epoch 98/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2751 - accuracy: 0.8374WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2849 - accuracy: 0.8291
# Epoch 99/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2867 - accuracy: 0.8264WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2835 - accuracy: 0.8291
# Epoch 100/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2818 - accuracy: 0.8268WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2823 - accuracy: 0.8291
# Epoch 101/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2825 - accuracy: 0.8266WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
#
# Epoch: 100, accuracy:0.8291,  loss:0.2809,
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2809 - accuracy: 0.8291
# Epoch 102/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2865 - accuracy: 0.8186WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2793 - accuracy: 0.8291
# Epoch 103/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2781 - accuracy: 0.8284WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2780 - accuracy: 0.8291
# Epoch 104/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2728 - accuracy: 0.8316WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2766 - accuracy: 0.8291
# Epoch 105/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2773 - accuracy: 0.8268WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2752 - accuracy: 0.8291
# Epoch 106/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2747 - accuracy: 0.8298WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2738 - accuracy: 0.8291
# Epoch 107/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2663 - accuracy: 0.8336WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2726 - accuracy: 0.8292
# Epoch 108/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2740 - accuracy: 0.8258WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2711 - accuracy: 0.8291
# Epoch 109/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2653 - accuracy: 0.8328WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2698 - accuracy: 0.8291
# Epoch 110/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2630 - accuracy: 0.8352WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2686 - accuracy: 0.8293
# Epoch 111/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2741 - accuracy: 0.8218WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2671 - accuracy: 0.8292
# Epoch 112/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2677 - accuracy: 0.8272WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2659 - accuracy: 0.8292
# Epoch 113/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2658 - accuracy: 0.8296WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2645 - accuracy: 0.8293
# Epoch 114/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2599 - accuracy: 0.8332WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2631 - accuracy: 0.8294
# Epoch 115/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2603 - accuracy: 0.8332WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2618 - accuracy: 0.8296
# Epoch 116/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2615 - accuracy: 0.8286WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2606 - accuracy: 0.8297
# Epoch 117/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2633 - accuracy: 0.8280WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2591 - accuracy: 0.8302
# Epoch 118/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2540 - accuracy: 0.8328WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2578 - accuracy: 0.8301
# Epoch 119/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2539 - accuracy: 0.8370WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2567 - accuracy: 0.8300
# Epoch 120/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2540 - accuracy: 0.8326WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2552 - accuracy: 0.8310
# Epoch 121/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2552 - accuracy: 0.8338WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2540 - accuracy: 0.8314
# Epoch 122/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2541 - accuracy: 0.8298WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2528 - accuracy: 0.8317
# Epoch 123/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2579 - accuracy: 0.8244WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2515 - accuracy: 0.8308
# Epoch 124/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2460 - accuracy: 0.8328WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2501 - accuracy: 0.8321
# Epoch 125/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2468 - accuracy: 0.8370WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2489 - accuracy: 0.8347
# Epoch 126/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2580 - accuracy: 0.8260WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2476 - accuracy: 0.8329
# Epoch 127/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2516 - accuracy: 0.8308WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2463 - accuracy: 0.8339
# Epoch 128/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2476 - accuracy: 0.8334WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2450 - accuracy: 0.8371
# Epoch 129/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2470 - accuracy: 0.8378WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2437 - accuracy: 0.8368
# Epoch 130/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2451 - accuracy: 0.8314WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2425 - accuracy: 0.8353
# Epoch 131/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2414 - accuracy: 0.8348WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2413 - accuracy: 0.8354
# Epoch 132/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2429 - accuracy: 0.8380WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2403 - accuracy: 0.8443
# Epoch 133/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2383 - accuracy: 0.8468WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2387 - accuracy: 0.8436
# Epoch 134/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2439 - accuracy: 0.8340WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2376 - accuracy: 0.8434
# Epoch 135/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2355 - accuracy: 0.8446WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2362 - accuracy: 0.8422
# Epoch 136/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2411 - accuracy: 0.8384WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2350 - accuracy: 0.8459
# Epoch 137/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2405 - accuracy: 0.8412WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2337 - accuracy: 0.8507
# Epoch 138/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2302 - accuracy: 0.8446WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2328 - accuracy: 0.8433
# Epoch 139/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2309 - accuracy: 0.8562WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2315 - accuracy: 0.8610
# Epoch 140/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2289 - accuracy: 0.8614WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2302 - accuracy: 0.8536
# Epoch 141/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2268 - accuracy: 0.8528WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2292 - accuracy: 0.8649
# Epoch 142/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2228 - accuracy: 0.8818WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2276 - accuracy: 0.8641
# Epoch 143/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2273 - accuracy: 0.8558WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2263 - accuracy: 0.8596
# Epoch 144/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2254 - accuracy: 0.8762WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2251 - accuracy: 0.8706
# Epoch 145/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2275 - accuracy: 0.8604WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2238 - accuracy: 0.8647
# Epoch 146/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2239 - accuracy: 0.8676WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2226 - accuracy: 0.8688
# Epoch 147/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2179 - accuracy: 0.8746WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2214 - accuracy: 0.8812
# Epoch 148/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2159 - accuracy: 0.8802WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2202 - accuracy: 0.8724
# Epoch 149/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2160 - accuracy: 0.8724WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2189 - accuracy: 0.8777
# Epoch 150/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2210 - accuracy: 0.8906WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2178 - accuracy: 0.8976
# Epoch 151/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2220 - accuracy: 0.8838WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2165 - accuracy: 0.8885
# Epoch 152/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2163 - accuracy: 0.8884WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2154 - accuracy: 0.8882
# Epoch 153/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2129 - accuracy: 0.8976WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# ...
# Epoch 349/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0626 - accuracy: 0.9900WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0644 - accuracy: 0.9888
# Epoch 350/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0634 - accuracy: 0.9892WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0641 - accuracy: 0.9891
# Epoch 351/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0633 - accuracy: 0.9906WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0637 - accuracy: 0.9890
# Epoch 352/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0639 - accuracy: 0.9878WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0634 - accuracy: 0.9889
# Epoch 353/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0647 - accuracy: 0.9888WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0632 - accuracy: 0.9889
# Epoch 354/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0630 - accuracy: 0.9874WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0629 - accuracy: 0.9891
# Epoch 355/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0602 - accuracy: 0.9894WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0626 - accuracy: 0.9888
# Epoch 356/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0613 - accuracy: 0.9896WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0623 - accuracy: 0.9888
# Epoch 357/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0631 - accuracy: 0.9892WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0620 - accuracy: 0.9890
# Epoch 358/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0642 - accuracy: 0.9882WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0619 - accuracy: 0.9889
# Epoch 359/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0616 - accuracy: 0.9896WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0614 - accuracy: 0.9889
# Epoch 360/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0630 - accuracy: 0.9876WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0614 - accuracy: 0.9889
# Epoch 361/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0618 - accuracy: 0.9882WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0611 - accuracy: 0.9888
# Epoch 362/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0612 - accuracy: 0.9878WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0608 - accuracy: 0.9890
# Epoch 363/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0591 - accuracy: 0.9902WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0604 - accuracy: 0.9891
# Epoch 364/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0659 - accuracy: 0.9868WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0602 - accuracy: 0.9890
# Epoch 365/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0566 - accuracy: 0.9900WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0603 - accuracy: 0.9890
# Epoch 366/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0635 - accuracy: 0.9876WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0598 - accuracy: 0.9891
# Epoch 367/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0622 - accuracy: 0.9880WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0595 - accuracy: 0.9889
# Epoch 368/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0600 - accuracy: 0.9888WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0595 - accuracy: 0.9889
# Epoch 369/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0577 - accuracy: 0.9888WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0591 - accuracy: 0.9890
# Epoch 370/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0601 - accuracy: 0.9888WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0588 - accuracy: 0.9892
# Epoch 371/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0563 - accuracy: 0.9912WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0584 - accuracy: 0.9891
# Epoch 372/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0602 - accuracy: 0.9896WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0583 - accuracy: 0.9891
# Epoch 373/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0563 - accuracy: 0.9910WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0580 - accuracy: 0.9892
# Epoch 374/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0590 - accuracy: 0.9870WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0577 - accuracy: 0.9891
# Epoch 375/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0565 - accuracy: 0.9898WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0576 - accuracy: 0.9890
# Epoch 376/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0573 - accuracy: 0.9888WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0579 - accuracy: 0.9885
# Epoch 377/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0607 - accuracy: 0.9866WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0583 - accuracy: 0.9886
# Epoch 378/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0638 - accuracy: 0.9862WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0576 - accuracy: 0.9892
# Epoch 379/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0598 - accuracy: 0.9878WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0568 - accuracy: 0.9888
# Epoch 380/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0539 - accuracy: 0.9900WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0566 - accuracy: 0.9890
# Epoch 381/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0552 - accuracy: 0.9894WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0563 - accuracy: 0.9890
# Epoch 382/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0575 - accuracy: 0.9890WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0559 - accuracy: 0.9890
# Epoch 383/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0567 - accuracy: 0.9874WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0559 - accuracy: 0.9891
# Epoch 384/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0525 - accuracy: 0.9900WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0557 - accuracy: 0.9890
# Epoch 385/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0515 - accuracy: 0.9916WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0558 - accuracy: 0.9890
# Epoch 386/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0510 - accuracy: 0.9914WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0553 - accuracy: 0.9890
# Epoch 387/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0571 - accuracy: 0.9868WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0552 - accuracy: 0.9890
# Epoch 388/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0541 - accuracy: 0.9882WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0550 - accuracy: 0.9889
# Epoch 389/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0553 - accuracy: 0.9874WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0547 - accuracy: 0.9889
# Epoch 390/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0561 - accuracy: 0.9892WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0545 - accuracy: 0.9892
# Epoch 391/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0574 - accuracy: 0.9862WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0542 - accuracy: 0.9891
# Epoch 392/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0551 - accuracy: 0.9898WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0540 - accuracy: 0.9892
# Epoch 393/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0545 - accuracy: 0.9888WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0539 - accuracy: 0.9892
# Epoch 394/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0557 - accuracy: 0.9868WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0537 - accuracy: 0.9892
# Epoch 395/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0534 - accuracy: 0.9890WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0535 - accuracy: 0.9892
# Epoch 396/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0554 - accuracy: 0.9888WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0535 - accuracy: 0.9892
# Epoch 397/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0481 - accuracy: 0.9914WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0533 - accuracy: 0.9891
# Epoch 398/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0548 - accuracy: 0.9902WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0532 - accuracy: 0.9895
# Epoch 399/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0556 - accuracy: 0.9882WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0531 - accuracy: 0.9896
# Epoch 400/400
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0519 - accuracy: 0.9882WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0535 - accuracy: 0.9885

# %%
# convert an array of values into a dataset matrix with zero padding
def create_dataset(dataset, look_back=1, pad=True):
    if pad:
        # dataset_pad = np.pad(dataset, ((look_back, look_back), (0, 0)), mode='constant', constant_values=0)
        dataset_pad = np.pad(dataset, ((look_back, look_back), (0, 0)), mode='edge')
    else:
        dataset_pad = dataset
        
    dataX = []
    for i in range(len(dataset_pad)-2*look_back):
        a = dataset_pad[i:(i+2*look_back+1), :]
        dataX.append(a)
    return np.array(dataX)

# print(df1[df1.index == 19938].describe())
# print(df1.tail())

def moving_average(a, n=5) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

# %%
# LSTM
LEARN_RATE = 0.002
TEST_SIZE = 0.00001
EPOCHS = 120
BATCH_SIZE = 500 # None # 1024
PAD_SIZE = 4
TIME_STEPS = 2*PAD_SIZE+1
N_FEATURES = len(df1.columns) - 2

print('LEARN_RATE:', LEARN_RATE, 'TEST_SIZE:', TEST_SIZE, 
      'EPOCHS:', EPOCHS, 'BATCH_SIZE:', BATCH_SIZE, 
      'PAD_SIZE:', PAD_SIZE, 'N_FEATURES:', N_FEATURES)

# seperate the features and targets
df1_data = np.array(df1)
x_trainwell1 = df1_data[:,:-2]
y_trainwell1 = df1_data[:,-2:]

# standize the matrix for training data
scaler = StandardScaler()
x_trainwell1 = scaler.fit_transform(x_trainwell1)

# print(x_trainwell1[:5,:], x_trainwell1[-5:,:])

x_data = create_dataset(x_trainwell1, PAD_SIZE)

x_train, x_test, y_train, y_test = train_test_split(x_data, y_trainwell1, test_size=TEST_SIZE, random_state=100)

if BATCH_SIZE is not None:
    STEPS_PER_EPOCH = len(x_train)//BATCH_SIZE
else: 
    STEPS_PER_EPOCH = 1
    
def build_model():
    model = keras.Sequential([
        layers.Bidirectional(layers.LSTM(64, return_sequences=False, 
#                                          dropout=0.2, 
#                                          recurrent_dropout=0.2,
                                         kernel_initializer=initializers.glorot_uniform(seed=1), 
                                         kernel_regularizer=regularizers.l2(0.0001)), 
                             input_shape=(TIME_STEPS, N_FEATURES)),
        layers.BatchNormalization(),
        layers.Dense(64,  kernel_initializer=initializers.glorot_uniform(seed=2), 
                     kernel_regularizer=regularizers.l2(0.01), activation='elu'),
        layers.BatchNormalization(),
        layers.Dropout(0.4, seed=100),
        layers.Dense(64,  kernel_initializer=initializers.glorot_uniform(seed=3), 
                     kernel_regularizer=regularizers.l2(0.01), activation='elu'),
        layers.BatchNormalization(),
        layers.Dropout(0.4, seed=200),
        layers.Dense(2, kernel_initializer=initializers.glorot_uniform(seed=4))
    ])

    lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
        LEARN_RATE,
        decay_steps=STEPS_PER_EPOCH*400,
        decay_rate=1,
        staircase=False)
    
    optimizer = tf.keras.optimizers.Adam(lr_schedule, beta_2=0.999, amsgrad=True)

    model.compile(loss='mean_squared_error',
                  optimizer=optimizer,
                  metrics=['mse'])
    return model


model = build_model()

# The patience parameter is the amount of epochs to check for improvement
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10000)

model.summary()

weight = np.ones(len(x_train))
SAMPLE_WEIGHT = weight

np.random.seed(0)

history = model.fit(
    x_train, y_train,
    batch_size=BATCH_SIZE, epochs=EPOCHS, 
#     validation_data=(x_test, y_test), 
    validation_split = 0.00001,
    verbose=1,
    sample_weight=SAMPLE_WEIGHT,
    callbacks=[early_stop, tfdocs.modeling.EpochDots()],
    shuffle=True)
# Out:
# LEARN_RATE: 0.002 TEST_SIZE: 1e-05 EPOCHS: 120 BATCH_SIZE: 500 PAD_SIZE: 4 N_FEATURES: 4
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 128)               35328
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 48,898
# Trainable params: 48,386
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/120
# 41/42 [============================>.] - ETA: 0s - loss: 23328.2676 - mse: 23326.7227
# Epoch: 0, loss:23331.6875,  mse:23330.1445,  val_loss:11738.8516,  val_mse:11737.2939,
# 42/42 [==============================] - 3s 74ms/step - loss: 23331.6875 - mse: 23330.1445 - val_loss: 11738.8516 - val_mse: 11737.2939
# Epoch 2/120
# 42/42 [==============================] - 2s 57ms/step - loss: 22174.9727 - mse: 22173.4297 - val_loss: 12294.5293 - val_mse: 12292.9980
# Epoch 3/120
# 42/42 [==============================] - 2s 57ms/step - loss: 20716.2539 - mse: 20714.7480 - val_loss: 12386.7041 - val_mse: 12385.2090
# Epoch 4/120
# 42/42 [==============================] - 2s 57ms/step - loss: 18960.8984 - mse: 18959.4199 - val_loss: 12626.4639 - val_mse: 12624.9971
# Epoch 5/120
# 42/42 [==============================] - 2s 56ms/step - loss: 17116.7969 - mse: 17115.3418 - val_loss: 11990.5977 - val_mse: 11989.1504
# Epoch 6/120
# 42/42 [==============================] - 2s 56ms/step - loss: 15188.1748 - mse: 15186.7344 - val_loss: 10782.4453 - val_mse: 10781.0078
# Epoch 7/120
# 42/42 [==============================] - 2s 56ms/step - loss: 13328.4854 - mse: 13327.0449 - val_loss: 9347.4238 - val_mse: 9345.9775
# Epoch 8/120
# 42/42 [==============================] - 2s 56ms/step - loss: 11334.4629 - mse: 11333.0117 - val_loss: 8544.4072 - val_mse: 8542.9512
# Epoch 9/120
# 42/42 [==============================] - 2s 57ms/step - loss: 9407.5186 - mse: 9406.0527 - val_loss: 7023.0825 - val_mse: 7021.6104
# Epoch 10/120
# 42/42 [==============================] - 2s 55ms/step - loss: 7538.0737 - mse: 7536.5957 - val_loss: 5620.4639 - val_mse: 5618.9771
# Epoch 11/120
# 42/42 [==============================] - 2s 55ms/step - loss: 5878.4194 - mse: 5876.9248 - val_loss: 3727.7407 - val_mse: 3726.2451
# Epoch 12/120
# 42/42 [==============================] - 2s 57ms/step - loss: 4477.9873 - mse: 4476.4883 - val_loss: 3292.7083 - val_mse: 3291.2039
# Epoch 13/120
# 42/42 [==============================] - 2s 55ms/step - loss: 3355.4551 - mse: 3353.9448 - val_loss: 2984.5696 - val_mse: 2983.0586
# Epoch 14/120
# 42/42 [==============================] - 2s 55ms/step - loss: 2492.4280 - mse: 2490.9141 - val_loss: 1943.5026 - val_mse: 1941.9897
# Epoch 15/120
# 42/42 [==============================] - 2s 56ms/step - loss: 1835.5345 - mse: 1834.0199 - val_loss: 1012.9660 - val_mse: 1011.4509
# Epoch 16/120
# 42/42 [==============================] - 2s 56ms/step - loss: 1386.6051 - mse: 1385.0898 - val_loss: 1023.9749 - val_mse: 1022.4594
# Epoch 17/120
# 42/42 [==============================] - 2s 58ms/step - loss: 1075.5114 - mse: 1073.9958 - val_loss: 495.5610 - val_mse: 494.0456
# Epoch 18/120
# 42/42 [==============================] - 2s 56ms/step - loss: 886.2913 - mse: 884.7753 - val_loss: 277.2870 - val_mse: 275.7711
# Epoch 19/120
# 42/42 [==============================] - 2s 57ms/step - loss: 728.2098 - mse: 726.6942 - val_loss: 159.7381 - val_mse: 158.2228
# Epoch 20/120
# 42/42 [==============================] - 2s 57ms/step - loss: 638.3097 - mse: 636.7924 - val_loss: 119.0826 - val_mse: 117.5634
# Epoch 21/120
# 42/42 [==============================] - 2s 59ms/step - loss: 596.3118 - mse: 594.7921 - val_loss: 34.3214 - val_mse: 32.8004
# Epoch 22/120
# 42/42 [==============================] - 2s 55ms/step - loss: 563.7266 - mse: 562.2021 - val_loss: 53.6250 - val_mse: 52.1013
# Epoch 23/120
# 42/42 [==============================] - 2s 56ms/step - loss: 533.9647 - mse: 532.4404 - val_loss: 22.5678 - val_mse: 21.0409
# Epoch 24/120
# 42/42 [==============================] - 2s 58ms/step - loss: 518.7010 - mse: 517.1740 - val_loss: 12.4897 - val_mse: 10.9590
# Epoch 25/120
# 42/42 [==============================] - 2s 57ms/step - loss: 491.8123 - mse: 490.2814 - val_loss: 11.6596 - val_mse: 10.1291
# Epoch 26/120
# 42/42 [==============================] - 2s 55ms/step - loss: 493.6464 - mse: 492.1126 - val_loss: 53.5462 - val_mse: 52.0120
# Epoch 27/120
# 42/42 [==============================] - 2s 56ms/step - loss: 482.2707 - mse: 480.7356 - val_loss: 5.3910 - val_mse: 3.8561
# Epoch 28/120
# 42/42 [==============================] - 2s 56ms/step - loss: 482.0396 - mse: 480.5025 - val_loss: 1.6570 - val_mse: 0.1183
# Epoch 29/120
# 42/42 [==============================] - 2s 56ms/step - loss: 464.2868 - mse: 462.7469 - val_loss: 27.7595 - val_mse: 26.2183
# Epoch 30/120
# 42/42 [==============================] - 2s 57ms/step - loss: 475.9090 - mse: 474.3673 - val_loss: 3.6351 - val_mse: 2.0932
# Epoch 31/120
# 42/42 [==============================] - 2s 56ms/step - loss: 463.5877 - mse: 462.0448 - val_loss: 3.9333 - val_mse: 2.3897
# Epoch 32/120
# 42/42 [==============================] - 2s 56ms/step - loss: 459.1961 - mse: 457.6547 - val_loss: 2.3158 - val_mse: 0.7728
# Epoch 33/120
# 42/42 [==============================] - 2s 57ms/step - loss: 469.1130 - mse: 467.5683 - val_loss: 11.0042 - val_mse: 9.4585
# Epoch 34/120
# 42/42 [==============================] - 2s 58ms/step - loss: 448.0296 - mse: 446.4858 - val_loss: 1.9709 - val_mse: 0.4275
# Epoch 35/120
# 42/42 [==============================] - 2s 57ms/step - loss: 458.4594 - mse: 456.9141 - val_loss: 8.2795 - val_mse: 6.7341
# Epoch 36/120
# 42/42 [==============================] - 2s 56ms/step - loss: 461.8288 - mse: 460.2834 - val_loss: 4.2295 - val_mse: 2.6808
# Epoch 37/120
# 42/42 [==============================] - 2s 57ms/step - loss: 457.5690 - mse: 456.0193 - val_loss: 2.2979 - val_mse: 0.7478
# Epoch 38/120
# 42/42 [==============================] - 2s 56ms/step - loss: 449.4050 - mse: 447.8570 - val_loss: 6.3153 - val_mse: 4.7678
# Epoch 39/120
# 42/42 [==============================] - 2s 57ms/step - loss: 446.4555 - mse: 444.9062 - val_loss: 12.7581 - val_mse: 11.2090
# Epoch 40/120
# 42/42 [==============================] - 2s 56ms/step - loss: 448.4668 - mse: 446.9163 - val_loss: 19.3545 - val_mse: 17.8022
# Epoch 41/120
# 42/42 [==============================] - 2s 57ms/step - loss: 451.8223 - mse: 450.2717 - val_loss: 8.4719 - val_mse: 6.9218
# Epoch 42/120
# 42/42 [==============================] - 2s 56ms/step - loss: 455.6908 - mse: 454.1385 - val_loss: 25.9114 - val_mse: 24.3588
# Epoch 43/120
# 42/42 [==============================] - 2s 57ms/step - loss: 443.1082 - mse: 441.5563 - val_loss: 4.4894 - val_mse: 2.9384
# Epoch 44/120
# 42/42 [==============================] - 2s 56ms/step - loss: 448.2297 - mse: 446.6794 - val_loss: 23.8945 - val_mse: 22.3439
# Epoch 45/120
# 42/42 [==============================] - 2s 58ms/step - loss: 439.2171 - mse: 437.6661 - val_loss: 2.7235 - val_mse: 1.1733
# Epoch 46/120
# 42/42 [==============================] - 2s 58ms/step - loss: 432.5222 - mse: 430.9715 - val_loss: 11.7077 - val_mse: 10.1571
# Epoch 47/120
# 42/42 [==============================] - 2s 56ms/step - loss: 451.2366 - mse: 449.6865 - val_loss: 9.6760 - val_mse: 8.1271
# Epoch 48/120
# 42/42 [==============================] - 2s 58ms/step - loss: 449.0302 - mse: 447.4807 - val_loss: 22.0378 - val_mse: 20.4886
# Epoch 49/120
# 42/42 [==============================] - 2s 58ms/step - loss: 448.2054 - mse: 446.6558 - val_loss: 2.0348 - val_mse: 0.4864
# Epoch 50/120
# 42/42 [==============================] - 2s 57ms/step - loss: 427.9571 - mse: 426.4069 - val_loss: 3.8430 - val_mse: 2.2941
# Epoch 51/120
# 42/42 [==============================] - 2s 58ms/step - loss: 426.1638 - mse: 424.6150 - val_loss: 3.1672 - val_mse: 1.6187
# Epoch 52/120
# 42/42 [==============================] - 2s 57ms/step - loss: 429.9214 - mse: 428.3734 - val_loss: 27.2423 - val_mse: 25.6961
# Epoch 53/120
# 42/42 [==============================] - 2s 58ms/step - loss: 426.2011 - mse: 424.6541 - val_loss: 18.4077 - val_mse: 16.8599
# Epoch 54/120
# 42/42 [==============================] - 2s 59ms/step - loss: 435.7008 - mse: 434.1532 - val_loss: 1.8980 - val_mse: 0.3515
# Epoch 55/120
# 42/42 [==============================] - 2s 57ms/step - loss: 430.7987 - mse: 429.2517 - val_loss: 53.4571 - val_mse: 51.9101
# Epoch 56/120
# 42/42 [==============================] - 2s 57ms/step - loss: 421.9877 - mse: 420.4391 - val_loss: 4.9755 - val_mse: 3.4243
# Epoch 57/120
# 42/42 [==============================] - 2s 58ms/step - loss: 424.8127 - mse: 423.2619 - val_loss: 3.6619 - val_mse: 2.1117
# Epoch 58/120
# 42/42 [==============================] - 2s 58ms/step - loss: 421.9117 - mse: 420.3621 - val_loss: 4.0127 - val_mse: 2.4652
# Epoch 59/120
# 42/42 [==============================] - 2s 57ms/step - loss: 422.4798 - mse: 420.9340 - val_loss: 3.3565 - val_mse: 1.8106
# Epoch 60/120
# 42/42 [==============================] - 2s 57ms/step - loss: 430.5421 - mse: 428.9955 - val_loss: 6.7270 - val_mse: 5.1784
# Epoch 61/120
# 42/42 [==============================] - 2s 58ms/step - loss: 424.4103 - mse: 422.8625 - val_loss: 2.2530 - val_mse: 0.7067
# Epoch 62/120
# 42/42 [==============================] - 2s 58ms/step - loss: 423.5606 - mse: 422.0150 - val_loss: 11.5601 - val_mse: 10.0140
# Epoch 63/120
# 42/42 [==============================] - 2s 56ms/step - loss: 425.5577 - mse: 424.0124 - val_loss: 6.2464 - val_mse: 4.6998
# Epoch 64/120
# 42/42 [==============================] - 2s 57ms/step - loss: 419.6667 - mse: 418.1196 - val_loss: 18.9612 - val_mse: 17.4154
# Epoch 65/120
# 42/42 [==============================] - 2s 58ms/step - loss: 414.7024 - mse: 413.1565 - val_loss: 5.7056 - val_mse: 4.1595
# Epoch 66/120
# 42/42 [==============================] - 2s 57ms/step - loss: 420.5880 - mse: 419.0415 - val_loss: 4.0214 - val_mse: 2.4731
# Epoch 67/120
# 42/42 [==============================] - 2s 57ms/step - loss: 418.6385 - mse: 417.0912 - val_loss: 2.9053 - val_mse: 1.3581
# Epoch 68/120
# 42/42 [==============================] - 2s 57ms/step - loss: 412.1258 - mse: 410.5777 - val_loss: 3.9140 - val_mse: 2.3668
# Epoch 69/120
# 42/42 [==============================] - 2s 58ms/step - loss: 419.8925 - mse: 418.3450 - val_loss: 4.7161 - val_mse: 3.1712
# Epoch 70/120
# 42/42 [==============================] - 2s 57ms/step - loss: 415.5174 - mse: 413.9701 - val_loss: 6.1159 - val_mse: 4.5685
# Epoch 71/120
# 42/42 [==============================] - 2s 56ms/step - loss: 416.6285 - mse: 415.0796 - val_loss: 35.3986 - val_mse: 33.8505
# Epoch 72/120
# 42/42 [==============================] - 2s 56ms/step - loss: 412.2627 - mse: 410.7144 - val_loss: 6.7719 - val_mse: 5.2236
# Epoch 73/120
# 42/42 [==============================] - 2s 56ms/step - loss: 433.4756 - mse: 431.9281 - val_loss: 6.6199 - val_mse: 5.0714
# Epoch 74/120
# 42/42 [==============================] - 2s 57ms/step - loss: 418.7533 - mse: 417.2057 - val_loss: 38.7864 - val_mse: 37.2382
# Epoch 75/120
# 42/42 [==============================] - 3s 60ms/step - loss: 427.4365 - mse: 425.8893 - val_loss: 9.3550 - val_mse: 7.8075
# Epoch 76/120
# 42/42 [==============================] - 2s 59ms/step - loss: 418.2779 - mse: 416.7314 - val_loss: 2.8324 - val_mse: 1.2862
# Epoch 77/120
# 42/42 [==============================] - 2s 59ms/step - loss: 420.0586 - mse: 418.5112 - val_loss: 2.3126 - val_mse: 0.7641
# Epoch 78/120
# 42/42 [==============================] - 2s 58ms/step - loss: 411.7489 - mse: 410.2018 - val_loss: 8.7980 - val_mse: 7.2505
# Epoch 79/120
# 42/42 [==============================] - 2s 57ms/step - loss: 401.6017 - mse: 400.0548 - val_loss: 4.9749 - val_mse: 3.4267
# Epoch 80/120
# 42/42 [==============================] - 2s 57ms/step - loss: 412.4554 - mse: 410.9072 - val_loss: 29.0951 - val_mse: 27.5465
# Epoch 81/120
# 42/42 [==============================] - 2s 58ms/step - loss: 409.4839 - mse: 407.9354 - val_loss: 19.4422 - val_mse: 17.8937
# Epoch 82/120
# 42/42 [==============================] - 2s 57ms/step - loss: 407.8579 - mse: 406.3100 - val_loss: 4.1241 - val_mse: 2.5773
# Epoch 83/120
# 42/42 [==============================] - 2s 58ms/step - loss: 399.6960 - mse: 398.1491 - val_loss: 3.3360 - val_mse: 1.7879
# Epoch 84/120
# 42/42 [==============================] - 2s 57ms/step - loss: 421.0458 - mse: 419.4961 - val_loss: 14.6740 - val_mse: 13.1258
# Epoch 85/120
# 42/42 [==============================] - 2s 57ms/step - loss: 416.5909 - mse: 415.0439 - val_loss: 9.6639 - val_mse: 8.1172
# Epoch 86/120
# 42/42 [==============================] - 2s 57ms/step - loss: 407.0342 - mse: 405.4883 - val_loss: 2.0920 - val_mse: 0.5451
# Epoch 87/120
# 42/42 [==============================] - 2s 57ms/step - loss: 410.3979 - mse: 408.8494 - val_loss: 2.0539 - val_mse: 0.5071
# Epoch 88/120
# 42/42 [==============================] - 2s 57ms/step - loss: 391.1820 - mse: 389.6371 - val_loss: 4.5175 - val_mse: 2.9730
# Epoch 89/120
# 42/42 [==============================] - 2s 57ms/step - loss: 409.9393 - mse: 408.3938 - val_loss: 4.7131 - val_mse: 3.1660
# Epoch 90/120
# 42/42 [==============================] - 2s 58ms/step - loss: 402.6168 - mse: 401.0699 - val_loss: 33.3035 - val_mse: 31.7569
# Epoch 91/120
# 42/42 [==============================] - 2s 58ms/step - loss: 415.0499 - mse: 413.5028 - val_loss: 5.9163 - val_mse: 4.3706
# Epoch 92/120
# 42/42 [==============================] - 2s 59ms/step - loss: 402.4814 - mse: 400.9344 - val_loss: 9.9868 - val_mse: 8.4411
# Epoch 93/120
# 42/42 [==============================] - 2s 58ms/step - loss: 401.0292 - mse: 399.4834 - val_loss: 9.5163 - val_mse: 7.9720
# Epoch 94/120
# 42/42 [==============================] - 2s 58ms/step - loss: 415.4407 - mse: 413.8951 - val_loss: 13.9217 - val_mse: 12.3736
# Epoch 95/120
# 42/42 [==============================] - 2s 58ms/step - loss: 404.1446 - mse: 402.5975 - val_loss: 20.1510 - val_mse: 18.6048
# Epoch 96/120
# 42/42 [==============================] - 2s 57ms/step - loss: 392.5983 - mse: 391.0529 - val_loss: 1.9862 - val_mse: 0.4422
# Epoch 97/120
# 42/42 [==============================] - 2s 57ms/step - loss: 422.0435 - mse: 420.5001 - val_loss: 1.9735 - val_mse: 0.4303
# Epoch 98/120
# 42/42 [==============================] - 2s 59ms/step - loss: 403.5016 - mse: 401.9584 - val_loss: 12.7403 - val_mse: 11.1974
# Epoch 99/120
# 42/42 [==============================] - 2s 57ms/step - loss: 391.0997 - mse: 389.5585 - val_loss: 12.9753 - val_mse: 11.4343
# Epoch 100/120
# 42/42 [==============================] - 2s 58ms/step - loss: 404.0245 - mse: 402.4831 - val_loss: 11.6363 - val_mse: 10.0953
# Epoch 101/120
# 41/42 [============================>.] - ETA: 0s - loss: 393.2991 - mse: 391.7567
# Epoch: 100, loss:392.9156,  mse:391.3732,  val_loss:20.6269,  val_mse:19.0853,
# 42/42 [==============================] - 2s 59ms/step - loss: 392.9156 - mse: 391.3732 - val_loss: 20.6269 - val_mse: 19.0853
# Epoch 102/120
# 42/42 [==============================] - 2s 58ms/step - loss: 394.6013 - mse: 393.0599 - val_loss: 8.0147 - val_mse: 6.4756
# Epoch 103/120
# 42/42 [==============================] - 2s 57ms/step - loss: 397.0488 - mse: 395.5085 - val_loss: 4.3464 - val_mse: 2.8047
# Epoch 104/120
# 42/42 [==============================] - 2s 58ms/step - loss: 403.9394 - mse: 402.3971 - val_loss: 16.3372 - val_mse: 14.7952
# Epoch 105/120
# 42/42 [==============================] - 2s 57ms/step - loss: 406.8958 - mse: 405.3544 - val_loss: 14.2085 - val_mse: 12.6658
# Epoch 106/120
# 42/42 [==============================] - 2s 57ms/step - loss: 388.5824 - mse: 387.0370 - val_loss: 2.6551 - val_mse: 1.1113
# Epoch 107/120
# 42/42 [==============================] - 2s 59ms/step - loss: 403.2579 - mse: 401.7139 - val_loss: 4.3685 - val_mse: 2.8247
# Epoch 108/120
# 42/42 [==============================] - 2s 57ms/step - loss: 391.4155 - mse: 389.8711 - val_loss: 5.9547 - val_mse: 4.4096
# Epoch 109/120
# 42/42 [==============================] - 2s 58ms/step - loss: 405.2666 - mse: 403.7223 - val_loss: 7.9723 - val_mse: 6.4298
# Epoch 110/120
# 42/42 [==============================] - 2s 57ms/step - loss: 386.9959 - mse: 385.4530 - val_loss: 2.9872 - val_mse: 1.4440
# Epoch 111/120
# 42/42 [==============================] - 2s 58ms/step - loss: 385.1828 - mse: 383.6392 - val_loss: 6.5154 - val_mse: 4.9707
# Epoch 112/120
# 42/42 [==============================] - 2s 59ms/step - loss: 402.2127 - mse: 400.6677 - val_loss: 10.5802 - val_mse: 9.0369
# Epoch 113/120
# 42/42 [==============================] - 2s 59ms/step - loss: 403.5103 - mse: 401.9671 - val_loss: 3.5079 - val_mse: 1.9631
# Epoch 114/120
# 42/42 [==============================] - 2s 58ms/step - loss: 395.6426 - mse: 394.0982 - val_loss: 3.4972 - val_mse: 1.9521
# Epoch 115/120
# 42/42 [==============================] - 2s 58ms/step - loss: 399.5369 - mse: 397.9933 - val_loss: 2.6306 - val_mse: 1.0869
# Epoch 116/120
# 42/42 [==============================] - 2s 57ms/step - loss: 402.0771 - mse: 400.5324 - val_loss: 3.0522 - val_mse: 1.5070
# Epoch 117/120
# 42/42 [==============================] - 2s 57ms/step - loss: 392.2813 - mse: 390.7377 - val_loss: 2.0794 - val_mse: 0.5374
# Epoch 118/120
# 42/42 [==============================] - 2s 58ms/step - loss: 397.7358 - mse: 396.1943 - val_loss: 2.0997 - val_mse: 0.5570
# Epoch 119/120
# 42/42 [==============================] - 2s 58ms/step - loss: 388.1840 - mse: 386.6428 - val_loss: 2.5278 - val_mse: 0.9868
# Epoch 120/120
# 42/42 [==============================] - 2s 59ms/step - loss: 389.2556 - mse: 387.7140 - val_loss: 2.4375 - val_mse: 0.8952

# %%
plotter = tfdocs.plots.HistoryPlotter(smoothing_std=2)
plotter.plot({'Basic': history}, metric = "mse")
plt.ylabel('MSE')
plt.ylim([0,1000])

# check the result on train dataset only
train_predictions = model.predict(x_train)
result_plot(np.array(train_predictions), np.array(y_train))

# # check the result on test dataset only 
# result_plot(model.predict(x_test), y_test)

# check the result on all dataset
y_predict_all = model.predict(x_data)
result_plot(y_predict_all, y_trainwell1)

# square errors 
plt.figure()
plt.subplot(2, 1, 1)
plt.plot(np.square(np.subtract(y_predict_all[:, 0], y_trainwell1[:, 0]))) 

plt.subplot(2, 1, 2)
plt.plot(np.square(np.subtract(y_predict_all[:, 1], y_trainwell1[:, 1]))) 

plt.figure()
# weight = moving_average(y_train[:, 1], 500)
plt.plot(weight)
# plt.plot(moving_average(moving_average(SAMPLE_WEIGHT, 500), 500))
# Out:
# Root Mean Square Error is: 9.36505
# DTC: 4.58022
# DTS: 12.42698
# Root Mean Square Error is: 9.36483
# DTC: 4.58013
# DTS: 12.42668

# %% [markdown]
# ## <a>7. Prediction</a>

# %% [markdown]
# <a>Top</a>

# %%
# load test data from well 2
df2 = pd.read_csv('test.csv')

# DELETE features
df2.drop(DROP_FEATURE, axis=1, inplace=True)

# Remove missing 
for col in df2.columns.tolist():
    df2[col][df2[col]==-999] = np.nan

df2.dropna(axis=0, inplace=True)
df2_copy = df2.copy()

if REPLACE_ANOMALY:
    for item in logs[:-2]:
        if item == 'CAL':
            pass
        elif item == 'CNC':
            interpolateValue(item, 0.9, df=df2, df_orig=df2_copy)
        elif item == 'GR':
            anomaly = interpolateValue(item, 400, df=df2, df_orig=df2_copy)
        elif item == 'HRD':
            anomaly = interpolateValue(item, 25, df=df2, df_orig=df2_copy)
        elif item == 'HRM':
            anomaly = interpolateValue(item, 25, df=df2, df_orig=df2_copy)
        elif item == 'PE':
            anomaly = interpolateValue(item, 25, df=df2, df_orig=df2_copy)
        elif item == 'ZDEN':
            anomaly = interpolateValue(item, 3.1, 1.8, df=df2, df_orig=df2_copy)

df2_data = np.array(df2)

# predict rock type
predict_rock = model_bc.predict(df2_data)

shreshold = 0.12
predict_rock2 = predict_rock.copy()
predict_rock2[predict_rock > shreshold] = 1
predict_rock2[predict_rock <= shreshold] = 0
print(shreshold, np.sum(predict_rock2))

# predict_rock2[0:1991] = shreshold *2
# predict_rock2[1991:] = .0

df2_data_bc = np.column_stack((predict_rock2, df2_data)) 
df2_data_bc = scaler.transform(df2_data_bc)
x_trainwell2 = create_dataset(df2_data_bc, PAD_SIZE)

# print(x_trainwell2[:5, :], x_trainwell2[-5:, :])

y_trainwell2_predict = model.predict(x_trainwell2)

# load benchmark test data from well 2
df3 = pd.read_csv('real_result_20perc.csv')

# DELETE features
df3.drop(DROP_FEATURE, axis=1, inplace=True)

index = []
print(len(df2.columns))

# Insert index as depth column
df2_sorted = df2_copy
df2_sorted['IND'] = df2_sorted.index

df2_sorted = df2_copy.sort_values(by=[df2_copy.columns[1]])

def binarySearch(target, v):
    beg, end = 0, len(v)-1
    # print(beg, end)
    
    while beg + 1 < end:
        mid = beg + (end - beg) // 2
        
        # print(target, v[mid])
        if v[mid] < target:
            beg = mid
        else:
            end = mid
    
    #  print(target, v[beg], v[end], beg, end)
    if v[beg] == target:
        return beg
    if v[end] == target:
        return end
    return -999

for i, row in df3.iterrows():
    
    row = row.round(4)
    start = binarySearch(row[1].round(4), df2_sorted[df2_copy.columns[1]].round(4).tolist())
    # print('    ', i, start, df2_sorted.iloc[start, 1], row[1])
   
    while df2_sorted.iloc[start, 1].round(4) == row[1]:
        for k in range(len(df2_sorted.columns)-1):
            if row[k] != df2_sorted.iloc[start, k].round(4):
                break
            if k == len(df2_sorted.columns) - 2:
                # print(df2_sorted.iloc[start,-1])
                index.append(df2_sorted.iloc[start,-1])
        start += 1

# print(df3.iloc[0, :])
# print(df2.iloc[index[0], :])
print(len(df3.index), len(index))
if len(df3.index) != len(index):
    raise NameError('index length is wrong!')
    
# check the result
RMSE = result_plot(y_trainwell2_predict[index, :], np.array(df3.iloc[:,-2:]))
print(type(RMSE))

#prediction Plot

y_df3 = np.array(df3.iloc[:,-2:])

plt.subplots(nrows=2, ncols=1, figsize=(16,10))
plt.subplot(2, 1, 1)
plt.plot(y_trainwell2_predict[:,0])

real_data = np.stack((index, y_df3[:, -2]), axis = 1)
real_data_sort = real_data[np.argsort(real_data[:, 0])]
plt.scatter(index, y_df3[:, 0], color='red', s=5)
# plt.plot(real_data_sort[:, 0], real_data_sort[:, 1], color='m')
plt.xlim([0, 2000])

plt.subplot(2, 1, 2)
plt.plot(y_trainwell2_predict[:,1])

real_data = np.stack((index, y_df3[:, -1]), axis = 1)
real_data_sort = real_data[np.argsort(real_data[:, 0])]
plt.scatter(index, y_df3[:, 1], color='red', s=2)
plt.plot(df2_data_bc[:,0]*50)
# plt.plot(real_data_sort[:, 0], real_data_sort[:, 1], color='m')
plt.xlim([0, 2000])

# square errors 
plt.figure()
plt.subplots(nrows=2, ncols=1, figsize=(16,10))
plt.subplot(2, 1, 1)
plt.scatter(index, np.square(np.subtract(y_df3[:, 0], y_trainwell2_predict[index,0]))) 
# plt.xlim([0, 2000])

plt.subplot(2, 1, 2)
plt.scatter(index, np.square(np.subtract(y_df3[:, 1], y_trainwell2_predict[index,1])))
# plt.xlim([0, 2000])

date_time = datetime.now().strftime("%Y%m%d_%H_%M_%S")
rms = np.array2string(RMSE, precision=4)

output_result = pd.DataFrame({'DTC':y_trainwell2_predict[:,0], 'DTS':y_trainwell2_predict[:,1]})
output_result.head()
output_result.to_csv(path_or_buf='./result/'+rms+'-'+'_submission_'+date_time+'.csv', index=False)
# Out:
# 0.12 559.0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-396f0bb89d48> in <module>()
#      52
#      53 # load benchmark test data from well 2
# ---> 54 df3 = pd.read_csv('real_result_20perc.csv')
#      55
#      56 # DELETE features
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'real_result_20perc.csv'

# %%
plt.subplots(nrows=2, ncols=1, figsize=(16,10))
plt.subplot(2, 1, 1)
plt.plot(df1_orig['DTC'])
plt.plot(df1.index, df1['DTC'])

plt.subplot(2, 1, 2)
plt.plot(df1_orig['DTS'])
plt.plot(df1.index, df1['DTS'])

# %%
# check if there's any co-linearity between features
plt.scatter(df1_orig['DTC'][:5000], df1_orig['DTS'][:5000], s=20, c='red', alpha=0.2)
plt.scatter(df1_orig['DTC'][5000:], df1_orig['DTS'][5000:], s=20, c='yellow', alpha=0.2)
plt.scatter(df3['DTC'][:], df3['DTS'][:], s=20, c='green', alpha=0.2)
plt.xlim([40, 160])
plt.ylim([80, 500])

# %%
plt.scatter(df1['CNC'][:5000], df1['GR'][:5000], s=20, c='red', alpha=0.2)
plt.scatter(df1['CNC'][5000:], df1['GR'][5000:], s=20, c='yellow', alpha=0.2)
plt.scatter(df3['CNC'], df3['GR'], s=20, c='green', alpha=0.2)
plt.ylim([0, 400])

# %%
plt.scatter(df1['CNC'][:5000], df1['ZDEN'][:5000], s=20, c='red', alpha=0.2)
plt.scatter(df1['CNC'][5000:], df1['ZDEN'][5000:], s=20, c='yellow', alpha=0.2)
plt.scatter(df3['CNC'], df3['ZDEN'], s=20, c='green', alpha=0.2)
# plt.ylim([0, 500])

# %%
plt.scatter(df1['ZDEN'][:5000], df1['GR'][:5000], s=20, c='red', alpha=0.2)
plt.scatter(df1['ZDEN'][5000:], df1['GR'][5000:], s=20, c='yellow', alpha=0.2)
plt.scatter(df3['ZDEN'], df3['GR'], s=20, c='green', alpha=0.2)
plt.ylim([0, 400])

# %% [markdown]
# ## <a>8. Summary</a>

# %% [markdown]
# <a>Top</a>

# %% [markdown]
# The dataset contains two very different types of layers, so first use a RNN to predict the type. Then, use the bidirectional LSTM predict DTC and DTS.
